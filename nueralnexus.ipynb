# %%
# !pip install torch torchvision torchaudio
# !pip install transformers
# Out:
# Requirement already satisfied: torch in c:\users\haras\anaconda3\lib\site-packages (2.9.0)
# Requirement already satisfied: torchvision in c:\users\haras\anaconda3\lib\site-packages (0.24.0)
# Requirement already satisfied: torchaudio in c:\users\haras\anaconda3\lib\site-packages (2.9.0)
# Requirement already satisfied: filelock in c:\users\haras\anaconda3\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\haras\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\haras\anaconda3\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\haras\anaconda3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\haras\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\haras\anaconda3\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\haras\anaconda3\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: numpy in c:\users\haras\anaconda3\lib\site-packages (from torchvision) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\haras\anaconda3\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\haras\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\haras\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: transformers in c:\users\haras\anaconda3\lib\site-packages (4.57.1)
# Requirement already satisfied: filelock in c:\users\haras\anaconda3\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\haras\anaconda3\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\haras\anaconda3\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\haras\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\haras\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\haras\anaconda3\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\haras\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\haras\anaconda3\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\haras\anaconda3\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\haras\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\haras\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\haras\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\haras\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\haras\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\haras\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\haras\anaconda3\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\haras\anaconda3\lib\site-packages (from requests->transformers) (2025.10.5)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import torch
from transformers import AutoTokenizer , AutoModel

# %%
file_path = "training.1600000.processed.noemoticon.csv"

columns = ['sentiment','id','date','query','user','text']

df = pd.read_csv(file_path,encoding='latin-1',names = columns)

# %%
df.head()
# Out:
#    sentiment          id                          date     query  \
# 0          0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
print(df.shape)
# Out:
# (1600000, 6)

# %%
import re

def clean_tweet(text):
    text = str(text).lower()
    text = re.sub(r'@[\w_]+' , ' ' , text)
    text = re.sub(r'#',' ',text)
    text = re.sub(r'http\S+|www.\S+',' ',text)
    text = re.sub(r'\s+',' ',text).strip()
    return text

# %%
sample_df = df.sample(50000,random_state = 42).copy()
sample_df['clean_text'] = sample_df['text'].apply(clean_tweet)

print(sample_df[['text','clean_text']].head())
# Out:
#                                                      text  \
# 541200             @chrishasboobs AHHH I HOPE YOUR OK!!!
# 750     @misstoriblack cool , i have no tweet apps  fo...
# 766711  @TiannaChaos i know  just family drama. its la...
# 285055  School email won't open  and I have geography ...
# 705995                             upper airways problem
#
#                                                clean_text
# 541200                             ahhh i hope your ok!!!
# 750             cool , i have no tweet apps for my razr 2
# 766711  i know just family drama. its lame.hey next ti...
# 285055  school email won't open and i have geography s...
# 705995                              upper airways problem

# %%
sample_df['label'] = sample_df['sentiment'].replace(4,1)

# %%
print(sample_df['label'].head())
# Out:
# 541200    0
# 750       0
# 766711    0
# 285055    0
# 705995    0
# Name: label, dtype: int64

# %%
print(sample_df['label'].tail())
# Out:
# 199266    0
# 210814    0
# 180674    0
# 364859    0
# 172400    0
# Name: label, dtype: int64

# %%
sample_df['label'].value_counts()
# Out:
# label
# 1    25014
# 0    24986
# Name: count, dtype: int64

# %%
train_text,test_text,train_label,test_label = train_test_split(sample_df['clean_text'].values, sample_df['label'].values,test_size = 0.2,random_state = 42)

# %%
xtrain = train_text
xtest = test_text
ytrain = train_label
ytest = test_label

# %%
print(len(train_text))
print(len(test_text))
# Out:
# 40000
# 10000

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features=10000,stop_words = 'english')

xtrain_tfidf = vectorizer.fit_transform(train_text)
xtest_tfidf = vectorizer.transform(test_text)

# %%
print(xtrain_tfidf.shape)
print(xtest_tfidf.shape)
# Out:
# (40000, 10000)
# (10000, 10000)

# %%
print(vectorizer.get_feature_names_out()[:20])
# Out:
# ['00' '000' '00am' '00pm' '01' '02' '04' '05' '06' '07' '08' '09' '10'
#  '100' '1000' '100000' '1001' '100th' '101' '102']

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(max_iter = 200)

lr_model.fit(xtrain_tfidf,train_label)
# Out:
# LogisticRegression(max_iter=200)

# %%
ypred = lr_model.predict(xtest_tfidf)

# %%
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(ytest,ypred))
print(classification_report(ytest,ypred,target_names = ['Negitive','Positive']))
# Out:
# 0.7494
#               precision    recall  f1-score   support
#
#     Negitive       0.76      0.73      0.74      4977
#     Positive       0.74      0.77      0.75      5023
#
#     accuracy                           0.75     10000
#    macro avg       0.75      0.75      0.75     10000
# weighted avg       0.75      0.75      0.75     10000

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C' : [0.01,0.1,1,10],
    'penalty' : ['l1','l2','elasticnet','none'],
    'solver' : ['liblinear','lbfgs','newton-cg','sag','saga'],
    'max_iter' : [100,200,300],
    'l1_ratio' : [0,0.5,1]
}

grid = GridSearchCV(LogisticRegression(),param_grid,cv = 3,scoring = 'f1',verbose = 2,n_jobs = -1)

grid.fit(xtrain_tfidf,ytrain)
# Out:
# Fitting 3 folds for each of 720 candidates, totalling 2160 fits

# %%
print(grid.best_params_)
print(grid.best_score_)

# %%
ypred2 = grid.predict(xtest_tfidf)
print(accuracy_score(ytest,ypred2))
print(classification_report(ytest,ypred2,target_names = ['Negitive','Positive']))

# %%
from sklearn.svm import LinearSVC

sv_model = LinearSVC()

sv_model.fit(xtrain_tfidf,ytrain)
# Out:
# LinearSVC()

# %%
ypred3 = sv_model.predict(xtest_tfidf)
print(accuracy_score(ytest,ypred3))
print(classification_report(ytest,ypred3,target_names = ['Negitive','Positive']))
# Out:
# 0.7297
#               precision    recall  f1-score   support
#
#     Negitive       0.73      0.72      0.73      4977
#     Positive       0.73      0.74      0.73      5023
#
#     accuracy                           0.73     10000
#    macro avg       0.73      0.73      0.73     10000
# weighted avg       0.73      0.73      0.73     10000

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\haras\anaconda3\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\haras\anaconda3\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\haras\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\haras\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\haras\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\haras\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\haras\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.8)
# Requirement already satisfied: pillow in c:\users\haras\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\haras\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\haras\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\haras\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\haras\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\haras\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\haras\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\haras\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\haras\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\haras\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\haras\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential([
    Dense(256, activation='relu', input_shape=(xtrain_tfidf.shape[1],)),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid') 
])


model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=['accuracy']
)

# Train model
history = model.fit(
    xtrain_tfidf.toarray(), ytrain,
    epochs=5,
    batch_size=512,
    validation_split=0.1,
    verbose=1
)
# Out:
# C:\Users\haras\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 14s 143ms/step - accuracy: 0.6891 - loss: 0.5988 - val_accuracy: 0.7325 - val_loss: 0.5245
# Epoch 2/5
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7912 - loss: 0.4505 - val_accuracy: 0.7380 - val_loss: 0.5283
# Epoch 3/5
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.8288 - loss: 0.3891 - val_accuracy: 0.7295 - val_loss: 0.5660
# Epoch 4/5
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.8617 - loss: 0.3306 - val_accuracy: 0.7190 - val_loss: 0.6190
# Epoch 5/5
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.8969 - loss: 0.2613 - val_accuracy: 0.7097 - val_loss: 0.7264

# %%
y_pred = (model.predict(xtest_tfidf.toarray()) > 0.5).astype("int32")
print("Accuracy:", accuracy_score(ytest, y_pred))
print(classification_report(ytest, y_pred, target_names=['Negative', 'Positive']))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# Accuracy: 0.7184
#               precision    recall  f1-score   support
#
#     Negative       0.73      0.69      0.71      4977
#     Positive       0.71      0.75      0.73      5023
#
#     accuracy                           0.72     10000
#    macro avg       0.72      0.72      0.72     10000
# weighted avg       0.72      0.72      0.72     10000

# %%
sample_tweets = [" I like a girl", "I addicted to mobile"]
cleaned_tweets = [clean_tweet(t) for t in sample_tweets]
sample_tfidf = vectorizer.transform(cleaned_tweets)
predictions = lr_model.predict(sample_tfidf)
for tweet, label in zip(sample_tweets, predictions):
    print(f"{tweet} --> {'Positive' if label == 1 else 'Negative'}")
# Out:
#  I like a girl --> Positive
# I addicted to mobile --> Negative

# %%
import pickle
with open('vectorizer.pkl','wb') as f:
    pickle.dump(vectorizer,f)

with open('model.pkl','wb') as f:
    pickle.dump(lr_model,f)
    
import dill
with open('clean_tweet.pkl','wb') as f:
    dill.dump(clean_tweet,f)
